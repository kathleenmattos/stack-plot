# %% [markdown]
# # Stack Plot Example Using Random Numbers

# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create some random data to plot

# %%
x = range(1,21)
y1 = np.random.rand(20)
y2 = np.random.rand(20)

# print values to see what we have 
print(x)
print(y1)
print(y2)
# Out:
# range(1, 21)
# [0.02883722 0.94891218 0.41336655 0.6462043  0.40203586 0.84469374
#  0.35722407 0.08366612 0.79771601 0.58303831 0.03367152 0.71176124
#  0.79010617 0.04602377 0.49125041 0.48049254 0.23344872 0.1523493
#  0.06655942 0.1250421 ]
# [0.62521022 0.63055846 0.29572035 0.70814467 0.09501137 0.81140877
#  0.70542905 0.79533442 0.98709533 0.82500898 0.81070987 0.44617079
#  0.26775064 0.50685684 0.8724746  0.30513766 0.28422884 0.21334297
#  0.9198581  0.05806333]

# %%
# setup legend for plot
plt.plot([], [], color='r', label = 'y1')
plt.plot([], [], color='b', label = 'y2')

# setup the plot
plt.stackplot(x, y1, y2, colors= ['r', 'b'])
plt.title('Stack Plot Random Numbers')
plt.legend()
plt.show()
